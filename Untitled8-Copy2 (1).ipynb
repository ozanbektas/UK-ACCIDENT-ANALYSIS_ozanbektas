# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)

pd.options.display.float_format = '{:.2f}'.format
from random import randint
from sklearn import preprocessing

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score, auc, roc_curve, recall_score, f1_score, precision_score
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_selection import RFE
from sklearn.preprocessing import scale
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import ensemble
from sklearn.metrics import confusion_matrix as cm
from matplotlib.legend_handler import HandlerLine2D

# %%
df = pd.read_csv("C:/Users/ozann/OneDrive/Masaüstü/databank/car uk accidents/archive (1)/accidents_2012_to_2014.csv", low_memory=False)
df.head(10)
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760      -0.17
# 1  201201BS70002                 524930                  181430      -0.20
# 2  201201BS70003                 525860                  178080      -0.19
# 3  201201BS70004                 524980                  181030      -0.20
# 4  201201BS70005                 526170                  179200      -0.18
# 5  201201BS70006                 526090                  177600      -0.19
# 6  201201BS70007                 527780                  179680      -0.16
# 7  201201BS70008                 524010                  182080      -0.21
# 8  201201BS70010                 527710                  179290      -0.16
# 9  201201BS70011                 525120                  180060      -0.20
#
#    Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0     51.49             1                  3                   2
# ...

# %%
df = df.drop(columns=[
    'Accident_Index',
    'Special_Conditions_at_Site',
    'Carriageway_Hazards',
    'Junction_Detail',
    'LSOA_of_Accident_Location',
    'Location_Easting_OSGR',
    'Location_Northing_OSGR',
    '1st_Road_Class',
    '1st_Road_Number',
    '2nd_Road_Class',
    '2nd_Road_Number'
])

# %%
print(df.Accident_Severity.value_counts())
# Out:
# 3    392610
# 2     66784
# 1      5303
# Name: Accident_Severity, dtype: int64

# %%
df
# Out:
#         Longitude  Latitude  Police_Force  Accident_Severity  \
# 0           -0.17     51.49             1                  3
# 1           -0.20     51.52             1                  3
# 2           -0.19     51.49             1                  3
# 3           -0.20     51.51             1                  3
# 4           -0.18     51.50             1                  3
# ...           ...       ...           ...                ...
# 464692      -3.42     55.26            98                  2
# 464693      -3.23     55.05            98                  3
# 464694      -3.23     54.99            98                  3
# 464695      -3.19     54.99            98                  2
# 464696      -3.35     55.11            98                  3
#
#         Number_of_Vehicles  Number_of_Casualties        Date  Day_of_Week  \
# 0                        2                     1  19/01/2012            5
# 1                        2                     1  04/01/2012            4
# ...

# %%
def cat_summary(data, cat_length, plot = False):

    print("# How many classes are there in variables?")
    print("----------------------------------------------------------------------------------")
    
    cat_names_less = [col for col in data.columns if len(data[col].unique()) < cat_length]
    cat_names_more = [col for col in data.columns if len(data[col].unique()) >= cat_length]
    print('Number of Classes <', str(cat_length) + ":", cat_names_less)
    print('Number of Classes >=', str(cat_length) + ":", cat_names_more, "\n\n")
    
    print("# Which variables are object variables that number of classes is more than", str(cat_length) + "?")
    print("----------------------------------------------------------------------------------")
    object_variables = [col for col in cat_names_more if data[col].dtype == "O"]
    more = [col for col in object_variables if len(data[col].unique()) >= cat_length]
    print('Number of Classes >', str(cat_length) + ":", more, "\n\n")
    
    print("# Number of Unique Classes")
    print("----------------------------------------------------------------------------------")
    for  i in data.columns:
        print(i, "(",str(data[i].dtypes),"):",data[i].nunique())
    print("\n\n")
    
    
    if plot:
        print("# Stats & Visualization")
    else:
        print("# Stats")
    print("-----------------------------------------------------------------------------------")
    
    for col in cat_names_less:
        print(pd.DataFrame({col: data[col].value_counts(),
                           "Ratio": 100 * data[col].value_counts()/ len (data)}), end = "\n\n\n")
        
        if plot:
            chart = sns.countplot(x = col, data = data)
            chart.set_xticklabels(chart.get_xticklabels(),rotation = 90)
            plt.show()
            
        print("#------------------------------------------------------------------------------ \n")
          
    


    
cat_summary(df, cat_length = 10, plot = True)
# Out:
# # How many classes are there in variables?
# ----------------------------------------------------------------------------------
# Number of Classes < 10: ['Accident_Severity', 'Day_of_Week', 'Road_Type', 'Speed_limit', 'Junction_Control', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions', 'Weather_Conditions', 'Road_Surface_Conditions', 'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident', 'Year']
# Number of Classes >= 10: ['Longitude', 'Latitude', 'Police_Force', 'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)']
#
#
# # Which variables are object variables that number of classes is more than 10?
# ----------------------------------------------------------------------------------
# Number of Classes > 10: ['Date', 'Time', 'Local_Authority_(Highway)']
#
#
# # Number of Unique Classes
# ...

# %%
df = df.dropna()

# %%
def num_plot(data, cat_length = 10, remove = ["Id"], hist_bins = 10, figsize = (20,4)):
    
    num_cols = [col for col in data.columns if df[col].dtypes != "O" 
                and len(data[col].unique()) >= cat_length]
    
    if len(remove) > 0:
        num_cols = list(set(num_cols).difference(remove))
        
    print("# Histogram & Boxplot \n")    
    for i in num_cols:
        fig, axes = plt.subplots(1, 3, figsize = figsize)
        data.hist(str(i), bins = hist_bins, ax=axes[0])
        data.boxplot(str(i),  ax=axes[1], vert=False);
        try: 
            sns.kdeplot(np.array(data[str(i)]))
        except: ValueError
        
        axes[1].set_yticklabels([])
        axes[1].set_yticks([])
        axes[0].set_title(i + " | Histogram")
        axes[1].set_title(i + " | Boxplot")
        axes[2].set_title(i + " | Density")
        plt.show()
        
        
num_plot(df, cat_length = 10, remove = ["Id"], hist_bins = 10, figsize = (20,4))
# Out:
# # Histogram & Boxplot

# %%
df.isna().sum()
# Out:
# Longitude                                           0
# Latitude                                            0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                               13
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# Road_Type                                           0
# Speed_limit                                         0
# Junction_Control                               178610
# Pedestrian_Crossing-Human_Control                   0
# Pedestrian_Crossing-Physical_Facilities             0
# Light_Conditions                                    0
# ...

# %%
fig, ax= plt.subplots(figsize=(10,10)) 
sns.heatmap(df.corr(), annot=True, linewidths=1, ax=ax, xticklabels=True, yticklabels=True);

# %%
df.hist(figsize = (13,10))
plt.show()

# %%
sns.pointplot(x= 'Accident_Severity', y='Number_of_Vehicles', data=df)
# Out:
# <AxesSubplot: xlabel='Accident_Severity', ylabel='Number_of_Vehicles'>

# %%
sns.pointplot(x= 'Accident_Severity', y='Number_of_Casualties', data=df)
# Out:
# <AxesSubplot: xlabel='Accident_Severity', ylabel='Number_of_Casualties'>

# %%
sns.pointplot(x= 'Accident_Severity', y='Urban_or_Rural_Area', data=df)
# Out:
# <AxesSubplot: xlabel='Accident_Severity', ylabel='Urban_or_Rural_Area'>

# %%
sns.pointplot(x= 'Accident_Severity', y='Speed_limit', data=df)
# Out:
# <AxesSubplot: xlabel='Accident_Severity', ylabel='Speed_limit'>

# %%
sns.pointplot(x= 'Accident_Severity', y='Year', data=df)
# Out:
# <AxesSubplot: xlabel='Accident_Severity', ylabel='Year'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464697 entries, 0 to 464696
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Longitude                                    464697 non-null  float64
#  1   Latitude                                     464697 non-null  float64
#  2   Police_Force                                 464697 non-null  int64
#  3   Accident_Severity                            464697 non-null  int64
#  4   Number_of_Vehicles                           464697 non-null  int64
#  5   Number_of_Casualties                         464697 non-null  int64
#  6   Date                                         464697 non-null  object
#  7   Day_of_Week                                  464697 non-null  int64
#  8   Time                                         464684 non-null  object
# ...

# %%
df["Time"].unique()
# Out:
# array(['20:35', '17:00', '10:07', ..., '04:18', '04:39', nan],
#       dtype=object)

# %%
df["Date"].unique()
# Out:
# array(['19/01/2012', '04/01/2012', '10/01/2012', ..., '24/11/2014',
#        '25/12/2014', '28/12/2014'], dtype=object)

# %%
df["Local_Authority_(Highway)"].unique()
# Out:
# array(['E09000020', 'E09000033', 'E09000013', 'E09000005', 'E09000001',
#        'E09000019', 'E09000030', 'E09000012', 'E09000028', 'E09000007',
#        'E09000022', 'E09000003', 'E09000014', 'E09000009', 'E09000018',
#        'E09000025', 'E09000027', 'EHEATHROW', 'E09000017', 'E09000031',
#        'E09000026', 'E09000002', 'E09000016', 'E09000008', 'E09000006',
#        'E09000032', 'E09000024', 'E09000023', 'E09000011', 'E09000004',
#        'E09000015', 'E09000010', 'E09000021', 'E09000029', 'E10000006',
#        'E10000017', 'E06000009', 'E06000008', 'E08000014', 'E08000012',
#        'E08000011', 'E08000013', 'E08000015', 'E08000003', 'E08000006',
#        'E08000008', 'E08000007', 'E08000001', 'E08000010', 'E08000009',
#        'E08000002', 'E08000005', 'E08000004', 'E06000050', 'E06000049',
#        'E06000007', 'E06000006', 'E06000048', 'E08000024', 'E08000022',
#        'E08000021', 'E08000023', 'E08000020', 'E06000047', 'E06000005',
# ...

# %%
df["Road_Type"].unique()
# Out:
# array(['Single carriageway', 'One way street', 'Roundabout',
#        'Dual carriageway', 'Slip road', 'Unknown'], dtype=object)

# %%
df["Pedestrian_Crossing-Human_Control"].unique()
# Out:
# array(['None within 50 metres', 'Control by other authorised person',
#        'Control by school crossing patrol'], dtype=object)

# %%
df["Pedestrian_Crossing-Physical_Facilities"].unique()
# Out:
# array(['Pedestrian phase at traffic signal junction',
#        'No physical crossing within 50 meters',
#        'non-junction pedestrian crossing', 'Zebra crossing',
#        'Central refuge', 'Footbridge or subway'], dtype=object)

# %%
df["Light_Conditions"].unique()
# Out:
# array(['Darkness: Street lights present and lit',
#        'Daylight: Street light present', 'Darkeness: No street lighting',
#        'Darkness: Street lights present but unlit',
#        'Darkness: Street lighting unknown'], dtype=object)

# %%
df["Weather_Conditions"].unique()
# Out:
# array(['Fine without high winds', 'Raining without high winds', 'Other',
#        'Snowing without high winds', 'Raining with high winds',
#        'Fine with high winds', 'Unknown', 'Fog or mist',
#        'Snowing with high winds'], dtype=object)

# %%
df["Did_Police_Officer_Attend_Scene_of_Accident"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df = df.drop(columns=["Local_Authority_(District)"])

# %%
df = df.drop(columns=["Date"])

# %%
df = df.drop(columns=["Time"])

# %%
df = df.drop(columns=["Local_Authority_(Highway)"])

# %%
df.head()
# Out:
#    Longitude  Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0      -0.17     51.49             1                  3                   2
# 1      -0.20     51.52             1                  3                   2
# 2      -0.19     51.49             1                  3                   2
# 3      -0.20     51.51             1                  3                   1
# 4      -0.18     51.50             1                  3                   1
#
#    Number_of_Casualties  Day_of_Week           Road_Type  Speed_limit  \
# 0                     1            5  Single carriageway           30
# 1                     1            4  Single carriageway           30
# 2                     1            3      One way street           30
# 3                     1            4  Single carriageway           30
# 4                     1            3  Single carriageway           30
#
#            Junction_Control Pedestrian_Crossing-Human_Control  \
# ...

# %%
df_2 = df.rename(columns = {"0":"Longitude",
                     "1":"Latitude",
                     "2":"Police_Force",
                     "3":"Accident_Severity",
                     "4":"Number_of_Vehicles",
                     "5":"Number_of_Casualties",
                     "6":"Day_of_Week",
                     "7":"Road_Type",
                     "8":"Speed_limit",
                     "9":"Junction_Control",
                     "10":"Pedestrian_Crossing-Human_Control",
                     "11":"Pedestrian_Crossing-Physical_Facilities",
                     "12":"Light_Conditions	",
                     "13":"Weather_Conditions",
                     "14":"Road_Surface_Conditions",
                     "15":"Urban_or_Rural_Area",
                     "16":"Did_Police_Officer_Attend_Scene_of_Accident",
                     "17":"Year"})

# %%
df_2.head()
# Out:
#    Longitude  Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0      -0.17     51.49             1                  3                   2
# 1      -0.20     51.52             1                  3                   2
# 2      -0.19     51.49             1                  3                   2
# 3      -0.20     51.51             1                  3                   1
# 4      -0.18     51.50             1                  3                   1
#
#    Number_of_Casualties  Day_of_Week           Road_Type  Speed_limit  \
# 0                     1            5  Single carriageway           30
# 1                     1            4  Single carriageway           30
# 2                     1            3      One way street           30
# 3                     1            4  Single carriageway           30
# 4                     1            3  Single carriageway           30
#
#            Junction_Control Pedestrian_Crossing-Human_Control  \
# ...

# %%
import pandas as pd
df_2.columns
# Out:
# Index(['Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Day_of_Week',
#        'Road_Type', 'Speed_limit', 'Junction_Control',
#        'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions', 'Urban_or_Rural_Area',
#        'Did_Police_Officer_Attend_Scene_of_Accident', 'Year'],
#       dtype='object')

# %%
df_2 = df.copy()
df_3 = df.copy()

# %%
df.head()
# Out:
#    Longitude  Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0      -0.17     51.49             1                  3                   2
# 1      -0.20     51.52             1                  3                   2
# 2      -0.19     51.49             1                  3                   2
# 3      -0.20     51.51             1                  3                   1
# 4      -0.18     51.50             1                  3                   1
#
#    Number_of_Casualties  Day_of_Week           Road_Type  Speed_limit  \
# 0                     1            5  Single carriageway           30
# 1                     1            4  Single carriageway           30
# 2                     1            3      One way street           30
# 3                     1            4  Single carriageway           30
# 4                     1            3  Single carriageway           30
#
#            Junction_Control Pedestrian_Crossing-Human_Control  \
# ...

# %%
df_2.loc[df_2.Did_Police_Officer_Attend_Scene_of_Accident == "Yes", "Did_Police_Officer_Attend_Scene_of_Accident"] = 1
df_2.loc[df_2.Did_Police_Officer_Attend_Scene_of_Accident == "No", "Did_Police_Officer_Attend_Scene_of_Accident"] = 0

# %%
df_2.head()
# Out:
#    Longitude  Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0      -0.17     51.49             1                  3                   2
# 1      -0.20     51.52             1                  3                   2
# 2      -0.19     51.49             1                  3                   2
# 3      -0.20     51.51             1                  3                   1
# 4      -0.18     51.50             1                  3                   1
#
#    Number_of_Casualties  Day_of_Week           Road_Type  Speed_limit  \
# 0                     1            5  Single carriageway           30
# 1                     1            4  Single carriageway           30
# 2                     1            3      One way street           30
# 3                     1            4  Single carriageway           30
# 4                     1            3  Single carriageway           30
#
#            Junction_Control Pedestrian_Crossing-Human_Control  \
# ...

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

# %%
df_3["Longitude"] = le.fit_transform(df_2.Longitude)

# %%
le.classes_
# Out:
# array([-7.509162, -7.48941 , -7.484821, ...,  1.758722,  1.758797,
#         1.759382])

# %%
df_3.Longitude.unique()
# Out:
# array([296790, 290465, 293074, ...,  41875,  44324,  38143], dtype=int64)

# %%
le.inverse_transform([1])
# Out:
# array([-7.48941])

# %%
df_3["Latitude"] = le.fit_transform(df_2.Latitude)

# %%
df_3["Police_Force"] = le.fit_transform(df_2.Police_Force)

# %%
df_3["Number_of_Vehicles"] = le.fit_transform(df_2.Number_of_Vehicles)

# %%
df_3["Number_of_Casualties"] = le.fit_transform(df_2.Number_of_Casualties)

# %%
df_3["Day_of_Week"] = le.fit_transform(df_2.Day_of_Week)

# %%
df_3["Road_Type"] = le.fit_transform(df_2.Road_Type)

# %%
df_3["Speed_limit"] = le.fit_transform(df_2.Speed_limit)

# %%
df_3["Junction_Control"] = le.fit_transform(df_2.Junction_Control)

# %%
df_3["Light_Conditions"] = le.fit_transform(df_2.Light_Conditions)

# %%
df_3["Weather_Conditions"] = le.fit_transform(df_2.Weather_Conditions)

# %%
df_3["Road_Surface_Conditions"] = le.fit_transform(df_2.Road_Surface_Conditions)

# %%
df_3["Urban_or_Rural_Area"] = le.fit_transform(df_2.Urban_or_Rural_Area)

# %%
df_3["Latitude"] = le.fit_transform(df_2.Latitude)

# %%
df_3["Did_Police_Officer_Attend_Scene_of_Accident"] = le.fit_transform(df_2.Did_Police_Officer_Attend_Scene_of_Accident)

# %%
df_3["Year"] = le.fit_transform(df_2.Year)

# %%
df_2 = df_2.rename(columns={'Pedestrian_Crossing-Human_Control': 'Pedestrian_Crossing_Human_Control'})

# %%
df_2 = df_2.rename(columns={'Pedestrian_Crossing-Physical_Facilities': 'Pedestrian_Crossing_Physical_Facilities'})

# %%
df_3["Pedestrian_Crossing_Human_Control"] = le.fit_transform(df_2.Pedestrian_Crossing_Human_Control)

# %%
df_3["Pedestrian_Crossing_Physical_Facilities"] = le.fit_transform(df_2.Pedestrian_Crossing_Physical_Facilities)

# %%
import pandas as pd

# %%
df_3
# Out:
#         Longitude  Latitude  Police_Force  Accident_Severity  \
# 0          296790     98520             0                  3
# 1          290465    108052             0                  3
# 2          293074     96347             0                  3
# 3          290560    106449             0                  3
# 4          293940     99984             0                  3
# ...           ...       ...           ...                ...
# 464692      36224    348713            50                  2
# 464693      41902    346957            50                  3
# 464694      41875    344568            50                  3
# 464695      44324    344856            50                  2
# 464696      38143    347639            50                  3
#
#         Number_of_Vehicles  Number_of_Casualties  Day_of_Week  Road_Type  \
# 0                        1                     0            4          3
# 1                        1                     0            3          3
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464697 entries, 0 to 464696
# Data columns (total 20 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Longitude                                    464697 non-null  int64
#  1   Latitude                                     464697 non-null  int64
#  2   Police_Force                                 464697 non-null  int64
#  3   Accident_Severity                            464697 non-null  int64
#  4   Number_of_Vehicles                           464697 non-null  int64
#  5   Number_of_Casualties                         464697 non-null  int64
#  6   Day_of_Week                                  464697 non-null  int64
#  7   Road_Type                                    464697 non-null  int32
#  8   Speed_limit                                  464697 non-null  int64
# ...

# %%
df_3.drop(['Pedestrian_Crossing-Human_Control'], axis=1, 
         inplace=True)

# %%
df_3.drop(['Pedestrian_Crossing-Physical_Facilities'], axis=1, inplace=True)

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464697 entries, 0 to 464696
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Longitude                                    464697 non-null  int64
#  1   Latitude                                     464697 non-null  int64
#  2   Police_Force                                 464697 non-null  int64
#  3   Accident_Severity                            464697 non-null  int64
#  4   Number_of_Vehicles                           464697 non-null  int64
#  5   Number_of_Casualties                         464697 non-null  int64
#  6   Day_of_Week                                  464697 non-null  int64
#  7   Road_Type                                    464697 non-null  int32
#  8   Speed_limit                                  464697 non-null  int64
# ...

# %%
df_3.head(10)
# Out:
#    Longitude  Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0     296790     98520             0                  3                   1
# 1     290465    108052             0                  3                   1
# 2     293074     96347             0                  3                   1
# 3     290560    106449             0                  3                   0
# 4     293940     99984             0                  3                   0
# 5     293682     94906             0                  3                   1
# 6     298679    101348             0                  3                   0
# 7     288053    110535             0                  3                   1
# 8     298472    100171             0                  3                   1
# 9     290935    102688             0                  3                   1
#
#    Number_of_Casualties  Day_of_Week  Road_Type  Speed_limit  \
# 0                     0            4          3            2
# ...

# %%
df_2.isna().sum()
# Out:
# Longitude                                           0
# Latitude                                            0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Day_of_Week                                         0
# Road_Type                                           0
# Speed_limit                                         0
# Junction_Control                               178610
# Pedestrian_Crossing_Human_Control                   0
# Pedestrian_Crossing_Physical_Facilities             0
# Light_Conditions                                    0
# Weather_Conditions                                  0
# Road_Surface_Conditions                           755
# Urban_or_Rural_Area                                 0
# Did_Police_Officer_Attend_Scene_of_Accident         2
# ...

# %%
df_3.shape
# Out:
# (464697, 18)

# %%
X = df_3.drop("Accident_Severity", axis = 1)
y = df_3["Accident_Severity"]

# %%
X.shape
# Out:
# (464697, 17)

# %%
y.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Accident_Severity, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state= 42)

# %%
X_train.shape
# Out:
# (394992, 17)

# %%
y_train.shape
# Out:
# (394992,)

# %%
y_test.shape
# Out:
# (69705,)

# %%
X_test.shape
# Out:
# (69705, 17)

# %%
nb = GaussianNB()
nb_model = nb.fit(X_train, y_train)

# %%
y_pred = nb_model.predict(X_test)

# %%
y_pred
# Out:
# array([3, 3, 3, ..., 3, 3, 3], dtype=int64)

# %%
df_3["Accident_Severity"].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
y_test
# Out:
# 372239    3
# 104062    3
# 242078    3
# 101329    3
# 187822    2
#          ..
# 444525    2
# 270364    3
# 294643    2
# 291218    3
# 63264     2
# Name: Accident_Severity, Length: 69705, dtype: int64

# %%
test_df_3 = pd.DataFrame({'accident_severity':y_test, 'estimated_accident_severity':y_pred})

# %%
test_df_3
# Out:
#         accident_severity  estimated_accident_severity
# 372239                  3                            3
# 104062                  3                            3
# 242078                  3                            3
# 101329                  3                            3
# 187822                  2                            3
# ...                   ...                          ...
# 444525                  2                            3
# 270364                  3                            3
# 294643                  2                            3
# 291218                  3                            3
# 63264                   2                            3
#
# [69705 rows x 2 columns]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8460368696650169

# %% [markdown]
# https://app.patika.dev/ozanbektas
